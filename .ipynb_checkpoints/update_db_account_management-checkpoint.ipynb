# %% [markdown]
# #    Engine for local db_account_management

# %%
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:tnbui115@localhost:3306/db_account_management')

# %%
df = pd.read_sql_table("users_actions", engine)
df
# Out:
#       id                                               name  action_type_id  \
# 0      1                                               None               1
# 1      2                                                  t               1
# 2      3  Germplasm (folder's level or germplasm set): d...               1
# 3      4        Variables (folder's level) -> display table               1
# 4      5              Folder -> Observations: display table               1
# ..   ...                                                ...             ...
# 611  616    Germplasm -> Get variables for share germplasms               1
# 612  617    Germplasm -> Share germplasms to research group               2
# 613  618             Phenome mobile -> Send field to mobile               7
# 614  619                  Phenome mobile -> get URL by user               1
# 615  620                                 PLC: create report               1
#
#      category_id  appmod_id
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        1.0
# 3            NaN        1.0
# 4            NaN        1.0
# ..           ...        ...
# 611        116.0        4.0
# 612        116.0        4.0
# 613        117.0        1.0
# 614        115.0        1.0
# 615        118.0        8.0
#
# [616 rows x 5 columns]

# %%
print('hello world')
